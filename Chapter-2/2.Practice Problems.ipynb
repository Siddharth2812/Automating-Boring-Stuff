# %% [markdown]
# # Practice Questions
# ###
# 1. What are the two values of the Boolean data type? How do you write them?
#
# ###
#     Two Boolean Data types are written as True and False
# ###
#
# ###
# 2. What are the three Boolean operators?
# ###
#     and or and not are the threee types of boolean operators
#
# ###
#
# 3. Write out the truth tables of each Boolean operator (that is, every possible combination of Boolean values for the operator and what they evaluate to).
# ###
#   ### And Table
#   | Expression | Evaluates to |
#   | --- | --- |
#   | True and True | True|
#   | True and False | False |
#   | False and True | False |
#   | False and False | False |
#
# ### OR Table
#   | Expression | Evaluates to |
#   | --- | --- |
#   | True or True| True |
#   | True or False | True |
#   | False or True | True |
#   | False or Flase | False |
#
# ### Not Table
#   | Expression | Evaluates to |
#   | --- | --- |
#   | not True | False |
#   | not Flse | True |
# ###
# 4. What do the following expressions evaluate to?
# ###
#     (5 > 4) and (3 == 5) = Trre and False = False
#     not (5 > 4) = Flase
#     (5 > 4) or (3 == 5) = True
#     not ((5 > 4) or (3 == 5)) = False
#     (True and True) and (True == False) = False
#     (not False) or (not True)  = True
# ###
# 5. What are the six comparison operators?
# ###
#     ==, !=, <, >, >=, <=
# ###
# 6. What is the difference between the equal to operator and the assignment operator?
# ###
#      '=' : Assignment operator used to give value to a variable
#      '==' : Equal to operator is used to check if the given two expressions are equal or not
# ###
#
# 7. Explain what a condition is and where you would use one.
# ###
#      Condition is used to check if a condition is satisfied or not in a given expression. These are used to decide when/how to execute based on the condition.
# ###
# 8. Identify the three blocks in this code:
# ###
#      Total 3 Bocks
#      * Outer If:
#      if spam == 10:
#       print('eggs')
#      * Inner if:
#          if spam > 5:
#         print('bacon')
#      * Else corresponding to inner if:
#          else:
#             print('ham')
# ###
#
# 10. What keys can you press if your program is stuck in an infinite loop?
# ###
#      Ctrl+C
# ###
# 11. What is the difference between break and continue?
# ###
#      Break is used to exit from a loop, Continue is used to skip the rest of the loop and start the next iteration.
# ###
# 12. What is the difference between range(10), range(0, 10), and range(0, 10, 1) in a for loop?
# ##
#      range(10) : To get numbers from 0 - 10 but not including 10
#      range(0, 10) : To get numbers from 0 - 10 including 0 but not 10
#      range(0,10,1) : Start from 0 include 0 , till 10 not including 10 but using a step of 1(usually the step is taken as 1)
# ###
#
# 14. If you had a function named bacon() inside a module named spam, how would you call it after importing spam?
# ###
#      Spam.bacon()
# ###
